# %%
import pandas as pd
import ast

auth_data = pd.read_csv('data/AuthorDataframe.csv')
paper_data = pd.read_csv('data/PaperDataset.csv')

# %%
auth_field = dict(zip(auth_data["AuthorID"], auth_data["Field"]))

for id_list in paper_data["authorIds"]:
    id_list = ast.literal_eval(id_list)
    # print(id_list)
    # print(id_list)

# %%
paper_data1 = paper_data
paper_data1[paper_data1["year"] > 2008.0]
paper_data1[paper_data1["fields"] != "Biology"]
# Out:
#                                         paperId  \
# 0      cd29131082e7cc7f4d9c333afed8b58d4cf44ce5
# 1      33b43646408161ad66a80ba8079d6e1aee244b65
# 2      3bda43967a06cf4611c5e5c8636477c230663201
# 3      3972ac23a6eaf45dea73cab154706088498018b8
# 4      5dabe81f9d6b53e75b0078322b3f0741f2788041
# ...                                         ...
# 28371  f204e92575b3c37a67a9103d6ed00292578978b3
# 28372  13d1782fc7384202e39af2aa9b3b77df2395bfe3
# 28373  c633303e309a59baeb0c62e80e22b01f0b44e101
# 28374  d2e119f3eab633aabf0e787df3540fa726145e87
# 28375  8473c423e58985893cdf3c2fb8ddc075a61a00ef
#
#                                                    title    year  \
# 0      Feature Reconstruction Based Channel Selection...  2021.0
# 1                        Wavelet multipliers and signals  1999.0
# 2      Principal Component Feature for Speech Recogni...  1999.0
# 3      Chasm in Hegemony: Explaining and Reproducing ...  2021.0
# ...
