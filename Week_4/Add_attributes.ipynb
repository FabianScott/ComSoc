# %%
import os
import pickle
import numpy as np
import pandas as pd
import networkx as nx
import netwulf as nw
from scipy import stats as st
import matplotlib.pyplot as plt

# %%
path_parent = os.path.dirname(os.getcwd())
os.chdir(path_parent)

# %%
def load_graph():
    stylized_network, config, G = nw.load("BigData/Graph.json")
    with open('BigData/graphdata.pickle', 'rb') as file:
        attribute_dict = pickle.load(file)
    nx.set_node_attributes(G, attribute_dict)
    return G

# %%
network, config = nw.visualize(G)

# %%
nw.save('BigData/Graph_with_attributes.json', network, config, G)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 nw.save('BigData/Graph_with_attributes.json', network, config, G)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\netwulf\io.py:62, in save(f, stylized_network, config, G)
#      60 else:
#      61     with open(f,'w') as _f:
# ---> 62         _write(_f,stylized_network,config,G)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\netwulf\io.py:16, in _write(f, stylized_network, config, G)
#      13 else:
#      14     js_G = None
# ---> 16 json.dump({
#      17             'stylized_network' : stylized_network,
#      18             'config' : config,
#      19             'Graph' : js_G
#      20           },
#      21           f,
#      22           separators=(',', ':'),
#      23           )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\simplejson\__init__.py:290, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, use_decimal, namedtuple_as_object, tuple_as_array, bigint_as_string, sort_keys, item_sort_key, for_json, ignore_nan, int_as_string_bitcount, iterable_as_array, **kw)
#     274     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     275         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     276         separators=separators, encoding=encoding,
#    (...)
#     286         int_as_string_bitcount=int_as_string_bitcount,
#     287         **kw).iterencode(obj)
#     288 # could accelerate with writelines in some versions of Python, at
#     289 # a debuggability cost
# --> 290 for chunk in iterable:
#     291     fp.write(chunk)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\simplejson\encoder.py:714, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     712         yield chunk
#     713 elif isinstance(o, dict):
# --> 714     for chunk in _iterencode_dict(o, _current_indent_level):
#     715         yield chunk
#     716 elif _use_decimal and isinstance(o, Decimal):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\simplejson\encoder.py:668, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     666             else:
#     667                 chunks = _iterencode(value, _current_indent_level)
# --> 668         for chunk in chunks:
#     669             yield chunk
#     670 if newline_indent is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\simplejson\encoder.py:668, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     666             else:
#     667                 chunks = _iterencode(value, _current_indent_level)
# --> 668         for chunk in chunks:
#     669             yield chunk
#     670 if newline_indent is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\simplejson\encoder.py:544, in _make_iterencode.<locals>._iterencode_list(lst, _current_indent_level)
#     542             else:
#     543                 chunks = _iterencode(value, _current_indent_level)
# --> 544         for chunk in chunks:
#     545             yield chunk
#     546 if first:
#     547     # iterable_as_array misses the fast path at the top
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\simplejson\encoder.py:668, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     666             else:
#     667                 chunks = _iterencode(value, _current_indent_level)
# --> 668         for chunk in chunks:
#     669             yield chunk
#     670 if newline_indent is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\simplejson\encoder.py:734, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     732         raise ValueError("Circular reference detected")
#     733     markers[markerid] = o
# --> 734 o = _default(o)
#     735 for chunk in _iterencode(o, _current_indent_level):
#     736     yield chunk
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\simplejson\encoder.py:273, in JSONEncoder.default(self, o)
#     255 def default(self, o):
#     256     """Implement this method in a subclass such that it returns
#     257     a serializable object for ``o``, or calls the base implementation
#     258     (to raise a ``TypeError``).
#    (...)
#     271
#     272     """
# --> 273     raise TypeError('Object of type %s is not JSON serializable' %
#     274                     o.__class__.__name__)
#
# TypeError: Object of type Series is not JSON serializable
